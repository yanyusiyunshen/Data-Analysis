# %%
from PIL.ImagePalette import random

1+1
# Out:
# 2

# %%
a=2
b=1222
a
# Out:
# 2

# %%
import matplotlib.pyplot as plt
plt.plot([1,0,4],[4,5,6])
plt.show()

# %%
from matplotlib import pyplot as plt
x = range(1,8)
y = [17,17,18,15,11,11,13]
plt.plot(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
x=range(1,8)#x轴的位置
y = [17, 17, 18, 15, 11, 11, 13]
#传入x和y，通过plot画折线图
plt.plot (x, y, color='red',alpha=0.5,linestyle='--',linewidth=3)
plt.show()

# %%
x=range(1,8)#x轴的位置
y = [17, 17, 18, 15, 11, 11, 13]#传入x和y，通过plot画折线图
plt.plot(x, y, marker='o')
plt.show()

# %%
from matplotlib import pyplot as plt
import  random
x = range(2,26,2) #x轴的位置
y =[random.randint(15, 30) for i in x]
# 设置图片的大小
"""figsize:指定figure的宽和高，单位为英寸;
    dpi参数指定绘图对象的分辨率，即每英寸多少个像素，缺省值为80，1英寸等于2.5cm,A4纸是21*30cn的纸张
    设置画布对象，figsize中对应的单位是英寸，dpi是每英寸有多少像素点"""
plt.figure(figsize=(20,8),dpi=80)

plt.plot(x,y)#传入x和y，通过plot画图
# plt.show()
# 保存(注意：要放在绘制的下面，并且plt.show()会释放figure资源，如果在显示图像之后保存图片将只能保存空图片。)
# plt.savefig('./t1.png')

# 图片的格式也可以保在为sVg这种矢量图格式，这种矢量图放在网页中放大后不会有锯齿
plt.savefig('./t2.svg')
